# %% [markdown]
# <a href="https://colab.research.google.com/github/srinath68/AMULANCE-ALERT-INDICATOR/blob/main/ambulance_alert_indicator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#include<stdio.h>
#include<LiquidCrystal.h>
LiquidCrystal lcd1(13,12,11,10,9,8);
LiquidCrystal lcd2(13,12,11,10,9,8);
LiquidCrystal lcd3(13,12,11,10,9,8);
LiquidCrystal lcd4(13,12,11,10,9,8);
int RED1=7;
int YELLOW1=7;
int GREEN1=7;
int RED2=6;
int YELLOW2=6;
int GREEN2=6;
int RED3=5;
int YELLOW3=5;
int GREEN3=5;
int RED4=3;
int YELLOW4=3;
int GREEN4=3;
int sensor1=4;
int sensor2=4;
int sensor3=4;
int sensor4=4;
int sensor1state=0;
int sensor2state=0;
int sensor3state=0;
int sensor4state=0;
void setup(){
    pinMode(7,OUTPUT);
    pinMode(6,OUTPUT);
    pinMode(5,OUTPUT);
    pinMode(3,OUTPUT);
    pinMode(4,INPUT);
    digitalWrite(7,LOW);
    digitalWrite(6,LOW);
    digitalWrite(5,LOW);
    digitalWrite(3,LOW);
    lcd1.begin(16,2);
    lcd1.print("WELCOME");
    delay(2000);
    lcd1.clear();
    lcd2.begin(16,2);
    lcd2.print("WELCOME");
    delay(2000);
    lcd2.clear();
    lcd3.begin(16,2);
    lcd3.print("WELCOME");
    delay(2000);
    lcd3.clear();
    lcd4.begin(16,2);
    lcd4.print("WELCOME");
    delay(2000);
    lcd4.clear();
}
void loop(){
    sensor1state=digitalRead(sensor1);
    sensor2state=digitalRead(sensor2);
    sensor3state=digitalRead(sensor3);
    sensor4state=digitalRead(sensor4);
 if(sensor1state==HIGH){
    lcd1.setCursor(0,1);
    lcd1.print("VEHICLE IS DETECTED");
     delay(2000);
        lcd1.clear();   
    }
    else{
        lcd1.setCursor(0,1);
        lcd1.print("VEHICLE IS NOT DETECTED");   
        delay(2000);
        lcd1.clear();     
    }
    if(sensor2state==HIGH){
        lcd2.setCursor(0,1);
        lcd2.print("VEHICLE IS DETECTED");
        delay(2000);
       lcd2.clear(); 
    }
else{
        lcd2.setCursor(0,2);
        lcd2.print("VEHICLE IS NOT DETECTED");
        delay(2000);
        lcd2.clear();   
    }
    if(sensor3state==HIGH){
      lcd3.setCursor(0,1);
        lcd3.print("VEHICLE IS DETECTED");
          delay(2000);
        lcd3.clear();  
    }
   else{
      lcd3.setCursor(0,2);
      lcd3.print("VEHICLE IS NOT DETECTED");
        delay(2000);
        lcd3.clear();     
    } 
    if(sensor4state==HIGH){
        lcd4.setCursor(0,1);
        lcd4.print("VEHICLE IS DETECTED");
        delay(2000);
        lcd4.clear();   
    }
    else{
       lcd4.setCursor(0,2);
         lcd4.print("VEHICLE IS NOT DETECTED");
        delay(2000);
        lcd4.clear(); 
    }
    digitalWrite(RED1,HIGH);
    digitalWrite(YELLOW1,LOW);
    digitalWrite(GREEN1,LOW);
    digitalWrite(RED2,HIGH);
    digitalWrite(YELLOW2,LOW);
    digitalWrite(GREEN2,LOW);
    digitalWrite(RED3,HIGH);
    digitalWrite(YELLOW3,LOW);
    digitalWrite(GREEN3,LOW);
    digitalWrite(RED4,HIGH);
    digitalWrite(YELLOW4,LOW);
    digitalWrite(GREEN4,LOW);
    lcd1.clear();
    lcd1.setCursor(0,6);
    lcd1.print("STOP");
    delay(5000);
    lcd1.clear();
    lcd2.setCursor(0,6);
    lcd2.print("STOP");
    delay(5000);
    lcd2.clear();
    lcd3.setCursor(0,6);
    lcd3.print("STOP");
    delay(5000);
    lcd3.clear();
    lcd4.setCursor(0,6);
    lcd4.print("STOP");
    delay(5000);
    lcd4.clear();
    digitalWrite(RED1,LOW);
    digitalWrite(YELLOW1,HIGH);
    digitalWrite(RED2,HIGH);
    digitalWrite(RED3,HIGH);
    digitalWrite(RED4,HIGH);
    digitalWrite(YELLOW2,LOW);
    digitalWrite(YELLOW3,LOW);
    digitalWrite(YELLOW4,LOW);
    digitalWrite(GREEN1,LOW);
    digitalWrite(GREEN2,LOW);
    digitalWrite(GREEN3,LOW);
    digitalWrite(GREEN4,LOW);
    lcd1.clear();
    lcd1.setCursor(0,2);
    lcd1.print("READY TO GO");
    delay(5000);
    lcd1.clear();
    lcd2.setCursor(0,2);
    lcd2.print("STOP");
    delay(5000);
    lcd2.clear();
    lcd3.setCursor(0,2);
    lcd3.print("STOP");
    delay(5000);
    lcd3.clear();
    lcd4.setCursor(0,2);
    lcd4.print("STOP");
    delay(5000);
    lcd4.clear();
    digitalWrite(RED1,LOW);
    digitalWrite(YELLOW1,LOW);
    digitalWrite(GREEN1,HIGH);
    digitalWrite(RED2,LOW);
    digitalWrite(YELLOW2,HIGH);
    digitalWrite(GREEN2,LOW);
    digitalWrite(RED3,HIGH);
    digitalWrite(YELLOW3,LOW);
    digitalWrite(GREEN3,LOW);
    digitalWrite(RED4,HIGH);
    digitalWrite(YELLOW4,LOW);
    digitalWrite(GREEN4,LOW);
    lcd1.setCursor(0,1);
    lcd1.print("MOVE");
    delay(5000);
    lcd1.clear();
    lcd2.print("READY TO GO");
    delay(5000);
    lcd2.clear();
    lcd3.setCursor(0,1);
    lcd3.print("STOP");
    delay(5000);
    lcd3.clear();
    lcd4.setCursor(0,1);
    lcd4.print("STOP");
    delay(5000);
    lcd4.clear();
    digitalWrite(RED1,HIGH);
    digitalWrite(YELLOW1,LOW);
    digitalWrite(GREEN1,LOW);
    digitalWrite(RED2,LOW);
    digitalWrite(YELLOW2,LOW);
    digitalWrite(GREEN2,HIGH);
    digitalWrite(RED3,LOW);
    digitalWrite(YELLOW3,HIGH);
    digitalWrite(GREEN3,LOW);
    digitalWrite(RED4,HIGH);
    digitalWrite(YELLOW4,LOW);
    digitalWrite(GREEN4,LOW);
    lcd1.setCursor(0,1);
    lcd1.print("STOP");
    delay(5000);
    lcd1.clear();
    lcd2.setCursor(0,1);
    lcd2.print("MOVE");
    delay(5000);
    lcd2.clear();
    lcd3.setCursor(0,1);
    lcd3.print("READY TO GO");
    delay(5000);
    lcd3.clear();
    lcd4.setCursor(0,1);
    lcd4.print("STOP");
    delay(5000);
    lcd4.clear();
    digitalWrite(RED1,LOW);
    digitalWrite(YELLOW1,HIGH);
    digitalWrite(GREEN1,LOW);
    digitalWrite(RED2,LOW);
    digitalWrite(YELLOW2,HIGH);
    digitalWrite(GREEN2,LOW);
    digitalWrite(RED3,LOW);
    digitalWrite(YELLOW3,LOW);
    digitalWrite(GREEN3,HIGH);
    digitalWrite(RED4,LOW);
    digitalWrite(YELLOW4,HIGH);
    digitalWrite(GREEN4,LOW);
    lcd1.setCursor(0,1);
    lcd1.print("READY TO GO");
    delay(5000);
    lcd1.clear();
    lcd2.setCursor(0,1);
    lcd2.print("MOVE");
    delay(5000);
    lcd2.clear();
    lcd3.setCursor(0,1);
    lcd3.print("READY TO GO");
    delay(5000);
    lcd3.clear();
    lcd4.setCursor(0,1);
    lcd4.print("STOP");
    delay(5000);
    lcd4.clear();
    digitalWrite(RED1,HIGH);
    digitalWrite(YELLOW1,LOW);
    digitalWrite(GREEN1,LOW);
    digitalWrite(RED2,LOW);
    digitalWrite(YELLOW2,HIGH);
    digitalWrite(GREEN2,LOW);
    digitalWrite(RED3,LOW);
    digitalWrite(YELLOW3,LOW);
    digitalWrite(GREEN3,HIGH);
    digitalWrite(RED4,LOW);
    digitalWrite(YELLOW4,HIGH);
    digitalWrite(GREEN4,LOW);
    lcd1.setCursor(0,1);
    lcd1.print("STOP");
    delay(5000);
    lcd1.clear();
    lcd2.setCursor(0,1);
    lcd2.print("READY TO GO");
    delay(5000);
    lcd2.clear();
    lcd3.setCursor(0,1);
    lcd3.print("MOVE");
    delay(5000);
    lcd3.clear();
    lcd4.setCursor(0,1);
    lcd4.print("READY TO GO");
    delay(5000);
    lcd4.clear();
    digitalWrite(RED1,LOW);
    digitalWrite(YELLOW1,HIGH);
    digitalWrite(GREEN1,LOW);
    digitalWrite(RED2,HIGH);
    digitalWrite(YELLOW2,LOW);
    digitalWrite(GREEN2,LOW);
    digitalWrite(RED3,LOW);
    digitalWrite(YELLOW3,HIGH);
    digitalWrite(GREEN3,LOW);
    digitalWrite(RED4,LOW);
    digitalWrite(YELLOW4,LOW);
    digitalWrite(GREEN4,HIGH);
    lcd1.setCursor(0,1);
    lcd1.print("READY TO GO");
    delay(5000);
    lcd1.clear();
    lcd2.setCursor(0,1);
    lcd2.print("STOP");
    delay(5000);
    lcd2.clear();
    lcd3.setCursor(0,1);
    lcd3.print("READY TO GO");
    delay(5000);
    lcd3.clear();
    lcd4.setCursor(0,1);
    lcd4.print("MOVE");
    delay(5000);
    lcd4.clear();
}
# Out:
#   File "<ipython-input-1-fa5c16289ac5>", line 3
#     LiquidCrystal lcd1(13,12,11,10,9,8);
#                      ^
# SyntaxError: invalid syntax
